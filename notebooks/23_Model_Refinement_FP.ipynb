# %%
# %pip install lightgbm
# %pip install xgboost
# Out:
# Requirement already satisfied: lightgbm in c:\f1-project\venv\lib\site-packages (4.6.0)
# Requirement already satisfied: numpy>=1.17.0 in c:\f1-project\venv\lib\site-packages (from lightgbm) (1.24.4)
# Requirement already satisfied: scipy in c:\f1-project\venv\lib\site-packages (from lightgbm) (1.10.1)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: xgboost in c:\f1-project\venv\lib\site-packages (2.1.4)
# Requirement already satisfied: numpy in c:\f1-project\venv\lib\site-packages (from xgboost) (1.24.4)
# Requirement already satisfied: scipy in c:\f1-project\venv\lib\site-packages (from xgboost) (1.10.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np

from sklearn.ensemble import RandomForestRegressor, StackingRegressor
from sklearn.linear_model import Ridge
from sklearn.metrics import mean_absolute_error, r2_score
from sklearn.model_selection import train_test_split

from xgboost import XGBRegressor

import joblib
import os

# %%
df = pd.read_csv("../data/processed/features_v2.csv")

print(df.shape)
print(df.columns)
# Out:
# (10908, 20)
# Index(['raceId', 'driverId', 'constructorId', 'circuitId', 'year', 'date',
#        'grid', 'positionOrder', 'points', 'avgLapTime_s', 'pitStopCount',
#        'driver_form_avg', 'constructor_form_avg', 'driver_experience',
#        'constructor_points_roll5', 'driver_circuit_avg_finish',
#        'circuitType_street', 'era_ground_effect', 'era_hybrid', 'era_v8'],
#       dtype='object')

# %%
target = "positionOrder"

# %%
drop_cols = [
    "raceId",
    "driverId",
    "constructorId",
    "date",
    "positionOrder",
    "avgLapTime_s",
    "points"
]

features = [col for col in df.columns if col not in drop_cols]

print("Number of features:", len(features))
# Out:
# Number of features: 13

# %%
train = df[df["year"] < 2020]
test  = df[df["year"] >= 2020]

X_train = train[features]
X_test  = test[features]

y_train = train[target]
y_test  = test[target]

# %%
rf = RandomForestRegressor(
    n_estimators=100,
    max_depth=8,
    random_state=42,
    n_jobs=-1
)

xgb = XGBRegressor(
    n_estimators=150,
    max_depth=4,
    random_state=42,
    n_jobs=-1
)

# %%
# Random Forest
rf.fit(X_train, y_train)
rf_preds = rf.predict(X_test)
print("RF R2:", r2_score(y_test, rf_preds))
# Out:
# RF R2: 0.48793309081123337

# %%
xgb.fit(X_train, y_train)
xgb_preds = xgb.predict(X_test)
print("XGB R2:", r2_score(y_test, xgb_preds))
# Out:
# XGB R2: 0.34881447267597065

# %%
print(X_train.shape)
# Out:
# (8842, 13)

# %%
def evaluate(name, y_true, y_pred):
    print(f"\n{name}")
    print("MAE:", mean_absolute_error(y_true, y_pred))
    print("R2:", r2_score(y_true, y_pred))

evaluate("Random Forest", y_test, rf_preds)
evaluate("XGBoost", y_test, xgb_preds)

rf_r2 = r2_score(y_test, rf_preds)
xgb_r2 = r2_score(y_test, xgb_preds)

if rf_r2 >= xgb_r2:
    best_model = rf
    best_name = "random_forest"
    best_r2 = rf_r2
else:
    best_model = xgb
    best_name = "xgboost"
    best_r2 = xgb_r2

print(f"\nBest model selected: {best_name} (R2 = {best_r2:.4f})")
# Out:
# Random Forest
# MAE: 3.1479697587521445
# R2: 0.48793309081123337
#
# XGBoost
# MAE: 3.3773830989871576
# R2: 0.34881447267597065
#
# Best model selected: random_forest (R2 = 0.4879)

# %%
os.makedirs("models", exist_ok=True)

# Save model and feature list
joblib.dump(best_model, "../models/finishing_position_model.joblib")
joblib.dump(features, "../models/finishing_position_features.joblib")

print("Model and features saved successfully.")
# Out:
# Model and features saved successfully.
